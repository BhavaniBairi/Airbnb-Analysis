# %%
import pandas as pd
import numpy as np
import pymongo
import psycopg2
import streamlit as st
from pymongo import MongoClient
import plotly.express as px
from streamlit_option_menu import option_menu
pd.set_option('display.max_columns', None)
import urllib.parse
import seaborn as sns
import matplotlib.pyplot as plt

# %%
username = "Bhavani_Bairi"
password = "Havish@123$"
#Escaped username and Escaped password
escaped_username = urllib.parse.quote_plus(username)
escaped_password = urllib.parse.quote_plus(password)

connect_string = f'mongodb+srv://{escaped_username}:{escaped_password}@airbnb.d117ty2.mongodb.net/?retryWrites=true&w=majority&appName=Airbnb'

client = pymongo.MongoClient(connect_string)

# %%
db = client.sample_airbnb

# %%
col = db.listingsAndReviews

# %%
data = []
for i in col.find():
    data1 = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i.get('name'),
                Description = i['description'],
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                No_of_reviews = i['number_of_reviews'],
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Host_neighbourhood = i['host']['host_neighbourhood'],
                Street = i['address']['street'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Availability_30 = i['availability']['availability_30'],
                Availability_60 = i['availability']['availability_60'],
                Availability_90 = i['availability']['availability_90'],
                Availability_365 = i['availability']['availability_365'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact']
                )
    data.append(data1)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             Id                            Listing_url  \
# 0     10051164  https://www.airbnb.com/rooms/10051164
# 1     10030955  https://www.airbnb.com/rooms/10030955
# 2      1003530   https://www.airbnb.com/rooms/1003530
# 3     10009999  https://www.airbnb.com/rooms/10009999
# 4     10069642  https://www.airbnb.com/rooms/10069642
# ...        ...                                    ...
# 5550   9577071   https://www.airbnb.com/rooms/9577071
# 5551   9774127   https://www.airbnb.com/rooms/9774127
# 5552   9936016   https://www.airbnb.com/rooms/9936016
# 5553   9979991   https://www.airbnb.com/rooms/9979991
# 5554   9944044   https://www.airbnb.com/rooms/9944044
#
#                                       Name  \
# 0       Catete's Colonial Big Hause Room B
# 1              Apt Linda Vista Lagoa - Rio
# 2      New York City - Upper West Side Apt
# 3             Horto flat with small garden
# 4       Ótimo Apto proximo Parque Olimpico
# ...                                    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   Property_type        5555 non-null   object
#  5   Room_type            5555 non-null   object
#  6   Bed_type             5555 non-null   object
#  7   Min_nights           5555 non-null   int64
#  8   Max_nights           5555 non-null   int64
#  9   Cancellation_policy  5555 non-null   object
#  10  Accomodates          5555 non-null   int64
#  11  Total_bedrooms       5550 non-null   float64
#  12  Total_beds           5542 non-null   float64
#  13  No_of_reviews        5555 non-null   int64
#  14  Price                5555 non-null   object
# ...

# %%
from bson import Decimal128
from decimal import Decimal

df.Security_deposit = df.Security_deposit[~df.Security_deposit.isna()].astype(str).astype(float)
df.Cleaning_fee = df.Cleaning_fee[~df.Cleaning_fee.isna()].astype(str).astype(float)
df["Price"] = df['Price'].apply(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
df["Extra_people"] = df["Extra_people"].apply(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
df["Guests_included"] = df['Guests_included'].apply(lambda x: float(x.to_decimal()) if isinstance(x, Decimal128) else float(x))
df["Id"] = df["Id"].astype("Int64")

# %%
df.isna().sum()
# Out:
# Id                        0
# Listing_url               0
# Name                      0
# Description               0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            5
# Total_beds               13
# No_of_reviews             0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# Amenities                 0
# Host_id                   0
# Host_name                 0
# Host_neighbourhood        0
# Street                    0
# Country                   0
# Country_code              0
# Availability_30           0
# Availability_60           0
# Availability_90           0
# Availability_365          0
# Review_scores          1474
# Location_type             0
# Longitude                 0
# ...

# %%
df["Total_bedrooms"].fillna(df["Total_bedrooms"].mode()[0], inplace=True)
df["Total_beds"].fillna(df["Total_beds"].mode()[0], inplace=True)
df["Security_deposit"].fillna(df["Security_deposit"].median(),inplace=True)
df["Cleaning_fee"].fillna(df["Cleaning_fee"].median(), inplace=True)
df["Review_scores"].fillna(df["Review_scores"].median(),inplace=True)
# Out:
# C:\Users\rajub\AppData\Local\Temp\ipykernel_11920\588719992.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Total_bedrooms"].fillna(df["Total_bedrooms"].mode()[0], inplace=True)
# C:\Users\rajub\AppData\Local\Temp\ipykernel_11920\588719992.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Filling Empty values in Description and House rules columns
df.Description.replace(to_replace='',value='No description provided',inplace=True)
df.Amenities.replace(to_replace='',value='Information not available',inplace=True)
df.Host_neighbourhood.replace(to_replace='',value='Not mentioned', inplace=True)
# Out:
# C:\Users\rajub\AppData\Local\Temp\ipykernel_11920\2308539249.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Description.replace(to_replace='',value='No description provided',inplace=True)
# C:\Users\rajub\AppData\Local\Temp\ipykernel_11920\2308539249.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# Id                     0
# Listing_url            0
# Name                   0
# Description            0
# Property_type          0
# Room_type              0
# Bed_type               0
# Min_nights             0
# Max_nights             0
# Cancellation_policy    0
# Accomodates            0
# Total_bedrooms         0
# Total_beds             0
# No_of_reviews          0
# Price                  0
# Security_deposit       0
# Cleaning_fee           0
# Extra_people           0
# Guests_included        0
# Amenities              0
# Host_id                0
# Host_name              0
# Host_neighbourhood     0
# Street                 0
# Country                0
# Country_code           0
# Availability_30        0
# Availability_60        0
# Availability_90        0
# Availability_365       0
# Review_scores          0
# Location_type          0
# Longitude              0
# Latitude               0
# Is_location_exact      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Name Column has empty values and some duplicates hence dropping them
df.drop(labels=list(df[df.Name.duplicated(keep=False)].index),inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
# Converting dataframe to csv file and saving it
df.to_csv('Airbnb_data.csv',index=False)
